# %%
# MFQ notebook runtime bootstrap
import os
import sys
from pathlib import Path

_repo = Path.cwd()
while not (_repo / "pyproject.toml").is_file() and _repo != _repo.parent:
    _repo = _repo.parent
os.chdir(_repo)
sys.argv = [sys.argv[0], *['evidence/ch16/oracle.json']]

# %% [markdown]
# # 研究有效性、样本外与交易摩擦
#
# 时间不等式、多重检验阈值和 gross-cost-net 手算账本提供独立 oracle。

# %%
import runpy


if __name__ == "__main__":
    runpy.run_module("math_for_quant.ch16.research_validity", run_name="__main__")
