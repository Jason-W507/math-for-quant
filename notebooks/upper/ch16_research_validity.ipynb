# %%
# MFQ notebook runtime bootstrap
import os
from pathlib import Path

_repo = Path.cwd()
while not (_repo / "pyproject.toml").is_file() and _repo != _repo.parent:
    _repo = _repo.parent
os.chdir(_repo)

# %% [markdown]
# # 研究有效性、样本外与交易摩擦
#
# 时间不等式、多重检验阈值和 gross-cost-net 手算账本提供独立 oracle。

# %%
from pathlib import Path
from m4q.ch16.research_validity import main


main(Path("evidence/ch16/oracle.json"))
