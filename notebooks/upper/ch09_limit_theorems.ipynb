# %%
# MFQ notebook runtime bootstrap
import os
import sys
from pathlib import Path

_repo = Path.cwd()
while not (_repo / "pyproject.toml").is_file() and _repo != _repo.parent:
    _repo = _repo.parent
os.chdir(_repo)
sys.argv = [sys.argv[0], *['evidence/ch09/oracle.json']]

# %% [markdown]
# # LLN、CLT、集中界与重尾失效
#
# 理论均值、标准误、精确二项尾概率和 Hoeffding 上界均独立于模拟给出。

# %%
import runpy


if __name__ == "__main__":
    runpy.run_module("math_for_quant.ch09.limit_theorems", run_name="__main__")
