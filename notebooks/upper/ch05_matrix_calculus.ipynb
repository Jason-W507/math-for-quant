# %%
# MFQ notebook runtime bootstrap
import os
from pathlib import Path

_repo = Path.cwd()
while not (_repo / "pyproject.toml").is_file() and _repo != _repo.parent:
    _repo = _repo.parent
os.chdir(_repo)

# %% [markdown]
# # 二次型、Jacobian 链式法则与不可微反例
#
# 解析梯度先由微分形式手算；中心差分只负责独立交叉核验。

# %%
from m4q.ch05.matrix_calculus import main


main()
