# %%
# MFQ notebook runtime bootstrap
import os
from pathlib import Path

_repo = Path.cwd()
while not (_repo / "pyproject.toml").is_file() and _repo != _repo.parent:
    _repo = _repo.parent
os.chdir(_repo)

# %% [markdown]
# # 浮点误差、稳定算法与病态线性系统
#
# Decimal 与解析公式提供独立 oracle；NumPy float64 是被测实现。

# %%
from m4q.ch14.numerical_stability import main


main()
