# %%
# MFQ notebook runtime bootstrap
import os
import sys
from pathlib import Path

_repo = Path.cwd()
while not (_repo / "pyproject.toml").is_file() and _repo != _repo.parent:
    _repo = _repo.parent
os.chdir(_repo)
sys.argv = [sys.argv[0], *['evidence/ch14/oracle.json']]

# %% [markdown]
# # 浮点误差、稳定算法与病态线性系统
#
# Decimal 与解析公式提供独立 oracle；NumPy float64 是被测实现。

# %%
import runpy


if __name__ == "__main__":
    runpy.run_module("math_for_quant.ch14.numerical_stability", run_name="__main__")
