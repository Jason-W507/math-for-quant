# %%
# MFQ notebook runtime bootstrap
import os
from pathlib import Path

_repo = Path.cwd()
while not (_repo / "pyproject.toml").is_file() and _repo != _repo.parent:
    _repo = _repo.parent
os.chdir(_repo)

# %% [markdown]
# # 凸优化、KKT 与对偶
#
# 手算 KKT、对偶、灵敏度和最小方差组合是独立 oracle；投影梯度只负责
# 数值交叉验证。非凸驻点和约束资格失败问题用于展示 KKT 边界。

# %%
from m4q.ch13.convex_optimization import main


main()
