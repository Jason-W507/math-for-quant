# %%
# MFQ notebook runtime bootstrap
import os
import sys
from pathlib import Path

_repo = Path.cwd()
while not (_repo / "pyproject.toml").is_file() and _repo != _repo.parent:
    _repo = _repo.parent
os.chdir(_repo)
sys.argv = [sys.argv[0], *['evidence/ch15/oracle.json']]

# %% [markdown]
# # Monte Carlo、bootstrap 与方差缩减
#
# 解析积分、解析方差和可枚举小样本提供独立 oracle；伪随机模拟只是被测实现。

# %%
import runpy


if __name__ == "__main__":
    runpy.run_module("math_for_quant.ch15.monte_carlo", run_name="__main__")
