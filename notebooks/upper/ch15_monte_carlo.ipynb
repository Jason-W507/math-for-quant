# %%
# MFQ notebook runtime bootstrap
import os
from pathlib import Path

_repo = Path.cwd()
while not (_repo / "pyproject.toml").is_file() and _repo != _repo.parent:
    _repo = _repo.parent
os.chdir(_repo)

# %% [markdown]
# # Monte Carlo、bootstrap 与方差缩减
#
# 解析积分、解析方差和可枚举小样本提供独立 oracle；伪随机模拟只是被测实现。

# %%
from pathlib import Path
from m4q.ch15.monte_carlo import main


main(Path("evidence/ch15/oracle.json"))
