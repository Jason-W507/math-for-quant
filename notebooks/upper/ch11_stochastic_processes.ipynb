# %%
# MFQ notebook runtime bootstrap
import os
from pathlib import Path

_repo = Path.cwd()
while not (_repo / "pyproject.toml").is_file() and _repo != _repo.parent:
    _repo = _repo.parent
os.chdir(_repo)

# %% [markdown]
# # Markov、鞅、Poisson 与 Brownian 过程
#
# 矩阵幂、稳态方程、Poisson 矩、Brownian 协方差与有限空间条件概率
# 均由解析 oracle 给出；模拟只做固定容差的交叉验证。

# %%
from m4q.ch11.stochastic_processes import main


main()
