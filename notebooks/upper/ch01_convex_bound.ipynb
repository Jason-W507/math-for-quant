# %%
# MFQ notebook runtime bootstrap
import os
import sys
from pathlib import Path

_repo = Path.cwd()
while not (_repo / "pyproject.toml").is_file() and _repo != _repo.parent:
    _repo = _repo.parent
os.chdir(_repo)
sys.argv = [sys.argv[0], *['evidence/ch01/oracle.json']]

# %% [markdown]
# # 凸组合界与反例
#
# 本 notebook 是权威教学版本；期望值来自独立手算记录。

# %%
import runpy


if __name__ == "__main__":
    runpy.run_module("math_for_quant.ch01.convex_bound", run_name="__main__")
