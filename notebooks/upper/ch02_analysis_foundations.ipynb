# %%
# MFQ notebook runtime bootstrap
import os
from pathlib import Path

_repo = Path.cwd()
while not (_repo / "pyproject.toml").is_file() and _repo != _repo.parent:
    _repo = _repo.parent
os.chdir(_repo)

# %% [markdown]
# # 压缩迭代与非一致收敛反例
#
# 本 notebook 只复现独立手算账本；一般收敛结论仍由正文证明。

# %%
from m4q.ch02.analysis_foundations import main


main()
