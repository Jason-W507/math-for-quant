# %%
# MFQ notebook runtime bootstrap
import os
import sys
from pathlib import Path

_repo = Path.cwd()
while not (_repo / "pyproject.toml").is_file() and _repo != _repo.parent:
    _repo = _repo.parent
os.chdir(_repo)
sys.argv = [sys.argv[0], *['evidence/ch02/oracle.json']]

# %% [markdown]
# # 压缩迭代与非一致收敛反例
#
# 本 notebook 只复现独立手算账本；一般收敛结论仍由正文证明。

# %%
import runpy


if __name__ == "__main__":
    runpy.run_module("math_for_quant.ch02.analysis_foundations", run_name="__main__")
