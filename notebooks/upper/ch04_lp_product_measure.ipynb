# %%
# MFQ notebook runtime bootstrap
import os
import sys
from pathlib import Path

_repo = Path.cwd()
while not (_repo / "pyproject.toml").is_file() and _repo != _repo.parent:
    _repo = _repo.parent
os.chdir(_repo)
sys.argv = [sys.argv[0], *['evidence/ch04/oracle.json']]

# %% [markdown]
# # Lp 范数、求积误差与 Fubini 反例
#
# 解析范数、复合中点余项和双重级数计数先由手算给出；程序只复现这些 oracle。

# %%
import runpy


if __name__ == "__main__":
    runpy.run_module("math_for_quant.ch04.lp_product_measure", run_name="__main__")
