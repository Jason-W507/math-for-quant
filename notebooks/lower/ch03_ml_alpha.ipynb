# %%
# MFQ notebook runtime bootstrap
import os
import sys
from pathlib import Path

_repo = Path.cwd()
while not (_repo / "pyproject.toml").is_file() and _repo != _repo.parent:
    _repo = _repo.parent
os.chdir(_repo)
sys.argv = [sys.argv[0], *['evidence/lower-ch03/oracle.json']]

# %%
from __future__ import annotations

# %%
import runpy

# %%
if __name__ == "__main__":
    runpy.run_module("math_for_quant.lower.ml_alpha", run_name="__main__")
