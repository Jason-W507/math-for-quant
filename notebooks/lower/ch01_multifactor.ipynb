# %%
# MFQ notebook runtime bootstrap
import os
import sys
from pathlib import Path

_repo = Path.cwd()
while not (_repo / "pyproject.toml").is_file() and _repo != _repo.parent:
    _repo = _repo.parent
os.chdir(_repo)
sys.argv = [sys.argv[0], *['evidence/lower-ch01/oracle.json']]

# %% [markdown]
# # 多因子研究包：独立小面板验收
#
# 计算逻辑位于可导入模块；本文件是可直接运行的教学入口。

# %%
import runpy


if __name__ == "__main__":
    runpy.run_module("math_for_quant.lower.multifactor", run_name="__main__")
