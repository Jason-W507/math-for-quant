# %%
# MFQ notebook runtime bootstrap
import os
import sys
from pathlib import Path

_repo = Path.cwd()
while not (_repo / "pyproject.toml").is_file() and _repo != _repo.parent:
    _repo = _repo.parent
os.chdir(_repo)
sys.argv = [sys.argv[0], *['evidence/foundation/oracle.json']]

# %% [markdown]
# # 独立 oracle 最小实验
#
# 本文件就是权威教学 notebook；发布时只生成带输出的执行副本。

# %%
import runpy


if __name__ == "__main__":
    runpy.run_module(
        "math_for_quant.foundation.independent_oracle", run_name="__main__"
    )
