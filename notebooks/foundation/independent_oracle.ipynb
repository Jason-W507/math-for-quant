# %%
# MFQ notebook runtime bootstrap
import os
from pathlib import Path

_repo = Path.cwd()
while not (_repo / "pyproject.toml").is_file() and _repo != _repo.parent:
    _repo = _repo.parent
os.chdir(_repo)

# %% [markdown]
# # 独立 oracle 最小实验
#
# 本文件就是权威教学 notebook；发布时只生成带输出的执行副本。

# %%
from m4q.foundation.independent_oracle import main


main()
